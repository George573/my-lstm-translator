# %%
#!pip install kagglehub

# %%
import pandas

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "en-fr.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "dhruvildave/en-fr-translation-dataset",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipykernel_24953/2506508368.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# Downloading to /home/unicorn/.cache/kagglehub/datasets/dhruvildave/en-fr-translation-dataset/versions/2/en-fr.csv...
# 100%|██████████| 2.54G/2.54G [01:17<00:00, 35.1MB/s]
# Extracting zip of en-fr.csv...
# First 5 records:                                                   en  \
# 0  Changing Lives | Changing Society | How It Wor...
# 1                                           Site map
# 2                                           Feedback
# 3                                            Credits
# 4                                           Français
#
#                                                   fr
# 0  Il a transformé notre vie | Il a transformé la...
# 1                                       Plan du site
# 2                                        Rétroaction
# 3                                            Crédits
# 4                                            English

# %%
# df = pandas.read_csv('/home/unicorn/.cache/kagglehub/datasets/dhruvildave/en-fr-translation-dataset/versions/2/en-fr.csv')

# %%
df_unique = df.drop_duplicates(subset=['en'], keep='first')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 df_unique = df.drop_duplicates(subset=['en'], keep='first')
# ----> 2 df_unique.drop_na(inplace=True)
#
# File ~/my-lstm-translator/venv/lib64/python3.13/site-packages/pandas/core/generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'drop_na'

# %%
df_unique.dropna(inplace=True)

# %%
df_sampled = df.sample(frac=0.05)

# %%
len(df_sampled)
# Out:
# 1126019

# %%
df_sampled.to_csv('en-fr-1-mil.csv', index=False)

# %%
df_check = pandas.read_csv('en-fr-1-mil.csv')
